# %%
import pandas as pd
import numpy as np
import pickle
from nltk import everygrams
from sklearn.feature_extraction.text import CountVectorizer
from IPython.display import clear_output
import seaborn as sns
import matplotlib.pylab as plt
stopwords = pd.read_pickle('/Users/chinmayshrivastava/Desktop/OSCA/V4.0/stopwords.pickle')

# %%
database = pd.read_pickle('/Users/chinmayshrivastava/Desktop/OSCA/V4.0/scraping/databasefromhnandbc101.pickle')
headings = pd.read_pickle('/Users/chinmayshrivastava/Desktop/OSCA/V4.0/scraping/headingsfromhnandbc101.pickle')
paragraphs = pd.read_pickle('/Users/chinmayshrivastava/Desktop/OSCA/V4.0/scraping/paragraphsfromhnandbc101.pickle')
kws = pd.read_pickle('/Users/chinmayshrivastava/Desktop/OSCA/V4.0/extractingkws/manual.pickle')
synms = pd.read_csv('/Users/chinmayshrivastava/Desktop/OSCA/V4.0/extractingkws/synonymscsv.csv', delimiter='FUCK!!OFF#$', names=['synonyms'], engine='python')

# %%
headings.tail(60)
# Out:
#          tag                                        headingtext subheading  \
# 64623     h2      2 Solutions to improve blockchain scalability      64624
# 64624     h3                                1. Payment Channels       None
# 64625     h3             2. Sharding for Blockchain Scalability       None
# 64626     h3                                         Conclusion       None
# 64627  topic           Is Ethereum based ICOs coming to an end?      64628
# 64628     h1                                    Smart contracts      64629
# 64629     h2                                   New Developments       None
# 64630     h2                           New Programming Language       None
# 64631     h2                                    Native Identity       None
# 64632     h2                                   Consensus Method       None
# 64633  topic                        How to Scale Ethereum dApps      64634
# 64634     h1  DAppChain as a scaling solution for Ethereum D...       None
# 64635     h1  Other solutions under consideration for scalin...       None
# 64636  topic                          Top 10 Most Popular DApps      64637
# 64637     h2  Decentralized exchanges, games, and casino app...       None
# 64638     h2           The 10 most popular DApps are following:      64639
# 64639     h3                                           1. IDEX:       None
# 64640     h3                                      2. ForkDelta:       None
# 64641     h3                                  3. CryptoKitties:       None
# 64642     h3                                         4. Bancor:       None
# 64643     h3                              5. Ether Shrimp Farm:       None
# 64644     h3                                   6. Ether Online:       None
# 64645     h3                                        7. PoWH 3D:       None
# 64646     h3              8. Moon, Inc. – Idle Game + Pyramids:       None
# 64647     h3                                    9. Revolution1:       None
# 64648     h3                                     10. Etheremon:       None
# 64649     h3  DApps landscape is attracting many developers,...       None
# 64650  topic   Stellar Lumens (XLM) vs Ripple (XRP) – Which ...      64651
# 64651     h2                        XLM vs XRP: Key differences       None
# 64652     h2                                 More decentralized       None
# 64653     h2                                                          None
# 64654     h2                   Check out our other Comparisons:       None
# 64655     h2                                                          None
# 64656     h2             Similarities between the two protocols       None
# 64657  topic                   What Makes Blockchain Different?      64659
# 64658     h2  Blockchain has the following distinguishing fe...       None
# 64659     h1                          4 Qualities of Blockchain      64660
# 64660     h2                          The Challenge Scalability       None
# 64661  topic              What’s All the Fuss about Blockchain?      64662
# 64662     h2                       What then is the blockchain?      64663
# 64663     h3                          Transparent and self-care       None
# 64664     h3                           How does it do all that?       None
# 64665     h3                               Future of blockchain       None
# 64676       64677  [308848, 308849, 308850, 308851, 308852, 30885...
# 64677       64678                                   [308862, 308863]
# 64678       64679  [308864, 308865, 308866, 308867, 308868, 30886...
# 64679       64680                           [308876, 308877, 308878]
# 64680       64681                           [308879, 308880, 308881]
# 64681       64682                           [308882, 308883, 308884]
# 64682        None           [308885, 308886, 308887, 308888, 308889]

# %%
synms.head()
# Out:
#                       synonyms
# 0                     ,,,,,,,,
# 1             10clouds,,,,,,,,
# 2            34 attack,,,,,,,,
# 3            4everland,,,,,,,,
# 4  51 attack,51 attacks,,,,,,,

# %%
kwid_ = 0
kwid = {}
kwdata = {}

# %%
for synm in synms['synonyms']:
    temp = [element.lower() for element in synm.split(',') if len(element)!=0]
    kwdata[kwid_] = {'synonyms':{}, 'total':0}
    for element in temp:
        kwid[element] = kwid_
        kwdata[kwid_]['synonyms'][element] = 0
    kwid_+=1

# %%
len(kwid)
# Out:
# 919

# %%
kwdata
# Out:
# {0: {'synonyms': {}, 'total': 0},
#  1: {'synonyms': {'10clouds': 17}, 'total': 0},
#  2: {'synonyms': {'34 attack': 15}, 'total': 0},
#  3: {'synonyms': {'4everland': 18}, 'total': 0},
#  4: {'synonyms': {'51 attack': 243, '51 attacks': 76}, 'total': 0},
#  5: {'synonyms': {'aleph': 35}, 'total': 0},
#  6: {'synonyms': {'algorand': 140}, 'total': 0},
#  7: {'synonyms': {'algorithmic stablecoins': 78,
#    'algorithmic stable coins': 1,
#    'algorithmic stablecoin': 31,
#    'algorithmic stable coin': 2},
#   'total': 0},
#  8: {'synonyms': {'alphatoken': 17}, 'total': 0},
#  9: {'synonyms': {'alphawallet': 12}, 'total': 0},
#  10: {'synonyms': {'altcoin': 152, 'altcoins': 244}, 'total': 0},
#  11: {'synonyms': {'amazix': 22}, 'total': 0},
#  12: {'synonyms': {'anchor': 72}, 'total': 0},
#  13: {'synonyms': {'ape yacht club': 90}, 'total': 0},
#  14: {'synonyms': {'apecoin': 53}, 'total': 0},
#  15: {'synonyms': {'arbitrage': 110}, 'total': 0},
#  16: {'synonyms': {'arbitrum': 67}, 'total': 0},
#  17: {'synonyms': {'architecture': 1490}, 'total': 0},
#  18: {'synonyms': {'archive node': 30}, 'total': 0},
#  19: {'synonyms': {'arctouch': 33}, 'total': 0},
#  20: {'synonyms': {'artificial intelligence': 567, 'ai': 1660}, 'total': 0},
#  21: {'synonyms': {'asset tokenization': 149}, 'total': 0},
#  22: {'synonyms': {'asymmetric cryptography': 52}, 'total': 0},
#  23: {'synonyms': {'atom': 77}, 'total': 0},
#  24: {'synonyms': {'atomic swaps': 159}, 'total': 0},
#  25: {'synonyms': {'attarius': 5, 'attarius network': 19}, 'total': 0},
#  26: {'synonyms': {'augmented reality': 94, 'ar': 164}, 'total': 0},
#  27: {'synonyms': {'authentication': 390}, 'total': 0},
#  28: {'synonyms': {'autoglyphs': 50, 'autoglyph': 0}, 'total': 0},
#  29: {'synonyms': {'automated trading': 14}, 'total': 0},
#  30: {'synonyms': {'autonopoulos': 0}, 'total': 0},
#  72: {'synonyms': {'blockstack': 110}, 'total': 0},
#  73: {'synonyms': {'bnb chain': 73}, 'total': 0},
#  74: {'synonyms': {'bored ape': 119}, 'total': 0},
#  75: {'synonyms': {'bsc wallet': 31}, 'total': 0},
#  76: {'synonyms': {'bug bounties': 15, 'bug bounty': 25}, 'total': 0},
#  77: {'synonyms': {'buildscape': 0}, 'total': 0},
#  78: {'synonyms': {'byzantine fault tolerance': 224}, 'total': 0},
#  79: {'synonyms': {'byzantine generals problem': 43,
#    'byzantine general problem': 21},
#   'total': 0},
#  80: {'synonyms': {'callisto': 13}, 'total': 0},
#  81: {'synonyms': {'cardano': 572, 'cardano blockchain': 37}, 'total': 0},
#  82: {'synonyms': {'carlota': 18}, 'total': 0},
#  83: {'synonyms': {'casper network': 37, 'casper networks': 0}, 'total': 0},
#  84: {'synonyms': {'casperlabs': 27}, 'total': 0},
#  85: {'synonyms': {'cdx': 15}, 'total': 0},
#  86: {'synonyms': {'celo': 32}, 'total': 0},
#  87: {'synonyms': {'cennznet': 37}, 'total': 0},
#  88: {'synonyms': {'censorship': 503}, 'total': 0},
#  89: {'synonyms': {'centralised crypto exchanges': 0,
#    'centralized crypto exchanges': 44,
#    'centralised crypto exchange': 0,
#    'centralized crypto exchange': 7},
#   'total': 0},
#  90: {'synonyms': {'centralised exchanges': 5, 'centralized exchanges': 222},
#   'total': 0},
#  91: {'synonyms': {'centralised network': 5, 'centralized network': 41},
#   'total': 0},
#  92: {'synonyms': {'centralized': 2367, 'centralised': 190}, 'total': 0},
#  93: {'synonyms': {'cloud mining': 106}, 'total': 0},
#  94: {'synonyms': {'codenotary': 14}, 'total': 0},
#  95: {'synonyms': {'codezeros': 12}, 'total': 0},
#  96: {'synonyms': {'coinbase': 756}, 'total': 0},
#  97: {'synonyms': {'coinbase wallet': 58}, 'total': 0},
#  98: {'synonyms': {'coincheck': 30}, 'total': 0},
#  99: {'synonyms': {'coinfabrik': 17}, 'total': 0},
#  100: {'synonyms': {'coinjoin': 23}, 'total': 0},
#  101: {'synonyms': {'coinmama': 24}, 'total': 0},
#  102: {'synonyms': {'coinstats': 18}, 'total': 0},
#  103: {'synonyms': {'coinvest': 36}, 'total': 0},
#  104: {'synonyms': {'cold wallet': 56, 'cold wallets': 47}, 'total': 0},
#  105: {'synonyms': {'collateralised': 0,
#    'collateralized': 270,
#    'collateralization': 69,
#    'collateralisation': 2},
#   'total': 0},
#  106: {'synonyms': {'collateralised debt': 0, 'collateralized debt': 60},
#   'total': 0},
#  107: {'synonyms': {'collateralised stablecoin': 0,
#    'collateralized stablecoin': 27,
#    'collateralised stablecoins': 0,
#    'collateralized stablecoins': 91},
#   'total': 0},
#  108: {'synonyms': {'commodity backed': 32}, 'total': 0},
#  109: {'synonyms': {'composability': 35}, 'total': 0},
#  110: {'synonyms': {'concordium': 25}, 'total': 0},
#  111: {'synonyms': {'consensus': 2993,
#    'consensus mechanisms': 301,
#    'consensus mechanism': 444,
#    'consensus algorithm': 620,
#    'consensus algorithms': 504,
#    'consensus protocols': 142,
#    'consensus protocol': 287,
#    'consensus method': 100,
#    'consensus methods': 37},
#   'total': 0},
#  112: {'synonyms': {'consortium blockchain': 128,
#    'consortia': 92,
#    'consortium': 384},
#   'total': 0},
#  113: {'synonyms': {'coral protocol': 42}, 'total': 0},
#  114: {'synonyms': {'corda': 886, 'corda blockchain': 113}, 'total': 0},
#  115: {'synonyms': {'corda workspace': 12}, 'total': 0},
#  116: {'synonyms': {'cordapp': 25}, 'total': 0},
#  117: {'synonyms': {'cortex': 51}, 'total': 0},
#  118: {'synonyms': {'cosmos': 515}, 'total': 0},
#  119: {'synonyms': {'counterfeit drugs': 37, 'counterfeit drug': 12},
#   'total': 0},
#  120: {'synonyms': {'cpchain': 27}, 'total': 0},
#  121: {'synonyms': {'cronos': 47}, 'total': 0},
#  122: {'synonyms': {'cross chain bridges': 73, 'cross chain bridge': 32},
#   'total': 0},
#  123: {'synonyms': {'cross chain update': 25}, 'total': 0},
#  124: {'synonyms': {'crowdcreate': 101}, 'total': 0},
#  125: {'synonyms': {'crypterium': 56}, 'total': 0},
#  126: {'synonyms': {'crypto asset': 140,
#    'crypto assets': 613,
#    'cryptoasset': 53,
#    'cryptoassets': 114},
#   'total': 0},
#  127: {'synonyms': {'crypto bank': 26}, 'total': 0},
#  128: {'synonyms': {'crypto compliance': 99, 'cryptocurrency compliance': 36},
#   'total': 0},
#  129: {'synonyms': {'crypto custody': 73}, 'total': 0},
#  130: {'synonyms': {'crypto exchange': 0}, 'total': 0},
#  131: {'synonyms': {'crypto lending': 136, 'cryptocurrency lending': 16},
#   'total': 0},
#  132: {'synonyms': {'crypto liquidity': 38, 'cryptocurrency liquidity': 1},
#   'total': 0},
#  133: {'synonyms': {'crypto mining': 117,
#    'mining': 1831,
#    'blockchain mining': 7,
#    'cryptocurrency mining': 122},
#   'total': 0},
#  134: {'synonyms': {'crypto shilling': 20, 'cryptocurrency shilling': 7},
#   'total': 0},
#  135: {'synonyms': {'crypto staking platform': 1,
#    'crypto staking platforms': 12},
#   'total': 0},
#  136: {'synonyms': {'crypto tax': 39}, 'total': 0},
#  137: {'synonyms': {'crypto wallet': 278,
#    'crypto wallets': 237,
#    'cryptocurrency wallet': 108,
#    'cryptocurrency wallets': 71,
#    'blockchain wallet': 102,
#    'blockchain wallets': 28},
#   'total': 0},
#  138: {'synonyms': {'cryptocompare': 17}, 'total': 0},
#  139: {'synonyms': {'cryptocurrency': 6889,
#    'cryptocurrencies': 3961,
#    'crypto': 12307},
#   'total': 0},
#  140: {'synonyms': {'cryptoderivatives': 1}, 'total': 0},
#  141: {'synonyms': {'cryptoeconomics': 168,
#    'crypto economic': 18,
#    'cryptoeconomic': 60},
#   'total': 0},
#  142: {'synonyms': {'cryptographic hash': 109, 'cryptographic hashing': 71},
#   'total': 0},
#  143: {'synonyms': {'cryptography': 873}, 'total': 0},
#  144: {'synonyms': {'cryptohopper': 50}, 'total': 0},
#  145: {'synonyms': {'cryptokitties': 371}, 'total': 0},
#  146: {'synonyms': {'cryptomarket': 20}, 'total': 0},
#  147: {'synonyms': {'cryptonite': 28}, 'total': 0},
#  148: {'synonyms': {'cryptopunk': 79,
#    'cryptopunks': 134,
#    'crypto punk': 8,
#    'crypto punks': 25},
#   'total': 0},
#  149: {'synonyms': {'cryptos': 201}, 'total': 0},
#  150: {'synonyms': {'curve dao token': 49}, 'total': 0},
#  151: {'synonyms': {'custodial nft': 9, 'custodial nfts': 6}, 'total': 0},
#  152: {'synonyms': {'custodial wallet': 38, 'custodial wallets': 34},
#   'total': 0},
#  153: {'synonyms': {'custodian': 115}, 'total': 0},
#  154: {'synonyms': {'cyber attacks': 88,
#    'cyber attack': 13,
#    'cyberattack': 3,
#    'cyberattacks': 20},
#   'total': 0},
#  155: {'synonyms': {'cybersecurity': 242}, 'total': 0},
#  156: {'synonyms': {'dai': 361}, 'total': 0},
#  157: {'synonyms': {'dao': 1497,
#    'decentralised autonomous organisation': 5,
#    'decentralized autonomous organization': 193,
#    'decentralised autonomous organisations': 2,
#    'decentralized autonomous organizations': 176,
#    'daos': 668},
#   'total': 0},
#  158: {'synonyms': {'dao maker': 30}, 'total': 0},
#  159: {'synonyms': {'daolaunch': 13}, 'total': 0},
#  160: {'synonyms': {'dappchains': 16, 'dappchain': 5}, 'total': 0},
#  161: {'synonyms': {'dapps': 1678,
#    'decentralised applications': 26,
#    'decentralised application': 6,
#    'decentralized applications': 715,
#    'decentralized application': 253,
#    'dapp': 1345,
#    'decentralised app': 1,
#    'decentralized app': 116},
#   'total': 0},
#  162: {'synonyms': {'dark web': 57}, 'total': 0},
#  163: {'synonyms': {'dash': 263, 'dash platform': 39}, 'total': 0},
#  164: {'synonyms': {'ddos attack': 18, 'ddos attacks': 51}, 'total': 0},
#  165: {'synonyms': {'debt security': 25}, 'total': 0},
#  166: {'synonyms': {'decentraland': 273}, 'total': 0},
#  167: {'synonyms': {'decentralised': 441,
#    'decentralized': 6812,
#    'decentralisation': 148,
#    'decentralization': 2035},
#   'total': 0},
#  168: {'synonyms': {'decentralised cloud computing': 2,
#    'decentralized cloud computing': 16},
#   'total': 0},
#  169: {'synonyms': {'decentralised cloud storage': 6,
#    'decentralized cloud storage': 45},
#   'total': 0},
#  170: {'synonyms': {'decentralised custody': 0, 'decentralized custody': 27},
#   'total': 0},
#  171: {'synonyms': {'decentralised database': 1,
#    'decentralized database': 71,
#    'decentralised data': 21,
#    'decentralized data': 98},
#   'total': 0},
#  172: {'synonyms': {'decentralised exchange': 50,
#    'decentralised exchanges': 37,
#    'decentralized exchange': 351,
#    'decentralized exchanges': 442,
#    'crypto exchange': 274,
#    'cryptocurrency exchange': 246},
#   'total': 0},
#  173: {'synonyms': {'decentralised governance': 16,
#    'decentralized governance': 98},
#   'total': 0},
#  174: {'synonyms': {'decentralised identity': 15,
#    'decentralized identity': 187,
#    'decentralised identities': 1,
#    'decentralized identities': 34},
#   'total': 0},
#  550: {'synonyms': {'web3': 1153}, 'total': 0},
#  551: {'synonyms': {'white paper': 334, 'white papers': 82}, 'total': 0},
#  552: {'synonyms': {'world blockchain summit': 14}, 'total': 0},
#  553: {'synonyms': {'wrapping': 219}, 'total': 0},
#  554: {'synonyms': {'xrapid': 41}, 'total': 0},
#  555: {'synonyms': {'yellow network': 21}, 'total': 0},
#  556: {'synonyms': {'yield farming protocol': 1,
#    'yield farming protocols': 16},
#   'total': 0},
#  557: {'synonyms': {'zero knowledge proofs': 284,
#    'zero knowledge proof': 330,
#    'zkps': 81,
#    'zkp': 164},
#   'total': 0},
#  558: {'synonyms': {'zero trust': 28}, 'total': 0},
#  559: {'synonyms': {'zignaly': 19}, 'total': 0},
#  560: {'synonyms': {'zk rollups': 76,
#    'zk rollup': 22,
#    'zero knowledge rollups': 39,
#    'zero knowledge rollup': 2},
#   'total': 0},
#  561: {'synonyms': {'zksnarks': 68, 'zk snarks': 128, 'zksnark': 5},
#   'total': 0},
#  562: {'synonyms': {'zkstarks': 13,
#    'zkstark': 0,
#    'zk stark': 23,
#    'zk starks': 33},
#   'total': 0},
#  563: {'synonyms': {'hash table': 28, 'hash tables': 35}, 'total': 0},
#  564: {'synonyms': {'defi wallet': 14, 'defi wallets': 16}, 'total': 0},
#  565: {'synonyms': {'scantrust': 12}, 'total': 0},
#  566: {'synonyms': {'hyperledger indy': 153, 'hyper ledger indy': 0},
#   'total': 0},
#  567: {'synonyms': {'sap cloud': 31}, 'total': 0},
#  568: {'synonyms': {'quorum blockchain': 105}, 'total': 0},
#  569: {'synonyms': {'defi token': 32, 'defi tokens': 62}, 'total': 0},
#  570: {'synonyms': {'world economic forum': 63}, 'total': 0},
#  571: {'synonyms': {'trapdoor function': 13}, 'total': 0},
#  572: {'synonyms': {'scriptpubkey': 13}, 'total': 0},
#  573: {'synonyms': {'encryption': 617}, 'total': 0},
#  574: {'synonyms': {'public key encryption': 71}, 'total': 0},
#  575: {'synonyms': {'private key encryption': 24}, 'total': 0},
#  576: {'synonyms': {'public key cryptography': 105}, 'total': 0},
#  577: {'synonyms': {'private key cryptography': 7}, 'total': 0},
#  578: {'synonyms': {'digital dollar wallet': 51}, 'total': 0},
#  579: {'synonyms': {'hyperledger besu': 134, 'hyper ledger besu': 0},
#   'total': 0},
#  580: {'synonyms': {'hyperledger burrow': 48, 'hyper ledger burrow': 0},
#   'total': 0},
#  581: {'synonyms': {'hyperledger quilt': 39, 'hyper ledger quilt': 0},
#   'total': 0},
#  582: {'synonyms': {'decentralised identifier': 2,
#    'decentralised identifiers': 5,
#    'decentralized identifier': 4,
#    'decentralized identifiers': 31},
#   'total': 0},
#  583: {'synonyms': {'internet of money': 24}, 'total': 0},
#  584: {'synonyms': {'haul carrier': 12}, 'total': 0},
#  585: {'synonyms': {'cryptographic algorithms': 55,
#    'cryptographic algorithm': 24},
#   'total': 0},
#  586: {'synonyms': {'smart contract security': 66}, 'total': 0},
#  587: {'synonyms': {'cyber hacks': 13,
#    'cyber hack': 0,
#    'cyberhacks': 0,
#    'cyberhack': 0},
#   'total': 0},
#  588: {'synonyms': {'digital process automation': 15}, 'total': 0},
#  589: {'synonyms': {'contour blockchain': 43}, 'total': 0},
#  590: {'synonyms': {'hyperledger fabric consensus': 21}, 'total': 0},
#  591: {'synonyms': {'nep5': 76}, 'total': 0},
#  592: {'synonyms': {'nep8': 14}, 'total': 0},
#  593: {'synonyms': {'zeepin': 24}, 'total': 0},
#  594: {'synonyms': {'moonlight': 13}, 'total': 0},
#  595: {'synonyms': {'bitcoin segwit': 34}, 'total': 0},
#  596: {'synonyms': {'digixdao': 61}, 'total': 0},
#  597: {'synonyms': {'spectrecoin': 55}, 'total': 0},
#  598: {'synonyms': {'ethereum plasma': 31}, 'total': 0},
#  599: {'synonyms': {'ethereum wallet': 90}, 'total': 0}}

# %%
matrix = np.zeros((len(kwdata), len(kwdata)))

# %%
matrix.shape
# Out:
# (600, 600)

# %%
kwunique = {}
unid = 0
for kw in kwid:
    kwunique[kw] = unid
    unid+=1

# %%
hvector = CountVectorizer(vocabulary=kwunique, ngram_range=(1, 4))
pvector = CountVectorizer(vocabulary=kwunique, ngram_range=(1, 4))
h = hvector.fit_transform(headings['headingtext'])
p = pvector.fit_transform(paragraphs['text'])
hcount = h.toarray()
pcount = p.toarray()

# %%
psumrows = pcount.sum(axis=1)

# %%
len(psumrows)
# Out:
# 308890

# %%
def updatedict(somedict):
    tempd = {}
    somedictlist = sorted(somedict, key=len)
    for element in somedictlist:
        temp = everygrams(element.split(' '), max_len=len(element.split(' '))-1)
        temp = sorted(temp, key=len)
        temp = [' '.join(element) for element in temp]
        for ele in temp:
            if ele not in tempd:
                tempd[ele] = somedict[element]
            else:
                continue
    for element in tempd:
        if element in somedict:
            somedict[element] -= tempd[element]
    return somedict

headingcountfactor = 5
paragraphcountfactor = 1

for hid in headings.index:
    clear_output(wait=True)
    print(hid)
    htemp = {}
    ptemp = {}
    for kw1 in kwunique:
        if hcount[hid, kwunique[kw1]]!=0:
            htemp[kw1] = hcount[hid, kwunique[kw1]]
    for pgid in headings.iloc[hid]['paragraphs']:
        for kw2 in kwunique:
            if pcount[pgid, kwunique[kw2]]!=0:
                if kw2 not in ptemp:
                    ptemp[kw2] = pcount[pgid, kwunique[kw2]]
                else:
                    ptemp[kw2] += pcount[pgid, kwunique[kw2]]
    htemp = updatedict(htemp)
    ptemp = updatedict(ptemp)
    sumpara = 0
    for element in ptemp:
        sumpara += ptemp[element]
    for kw1 in htemp:
        kwdata[kwid[kw1]]['synonyms'][kw1] += htemp[kw1]*headingcountfactor
        for kw2 in ptemp:
            kwdata[kwid[kw2]]['synonyms'][kw2] += ptemp[kw1]*paragraphcountfactor
            matrix[kwid[kw1], kwid[kw2]] += ptemp[kw2]/sumpara
# Out:
# 64682

# %%
matrix[57, 57]
# Out:
# 2929.8276558926705

# %%
matrix
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.27922078, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.26785714, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 2.67590188, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.49292929,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.58333333]])

# %%
ax = sns.heatmap(matrix, linewidth=0.5)
plt.show()

# %%
with open('largematrix.pickle', 'wb') as file:
    pickle.dump(matrix, file)

# %%
with open('synonymsdata.pickle', 'wb') as file:
    pickle.dump(kwdata, file)

# %%
with open('kwid.pickle', 'wb') as file:
    pickle.dump(kwid, file)

# %%
for kw in kwdata:
    temp = 0
    for synm in kwdata[kw]['synonyms']:
        temp += kwdata[kw]['synonyms'][synm]
    kwdata[kw]['total'] = temp

for kw in kwdata:
    name = ''
    for synm in kwdata[kw]['synonyms']:
        if len(name)==0:
            name = synm
        elif kwdata[kw]['synonyms'][synm]>kwdata[kw]['synonyms'][name]:
            name = synm
    kwdata[kw]['name'] = name

# %%
kwdata[kwid['crypto']]
# Out:
# {'synonyms': {'cryptocurrency': 6889,
#   'cryptocurrencies': 3961,
#   'crypto': 12307},
#  'total': 23157,
#  'name': 'crypto'}

# %%
def out1(a):
    return a[1]

def out0(a):
    return a[0]

name_ = 'non fungible token'
toprint = []
for element in list(matrix[kwid[name_]]):
    if element>0.05*max(list(matrix[kwid[name_]])): #0.1*max(list(matrix[kwid[name_]]))
        toprint.append([kwdata[list(matrix[kwid[name_]]).index(element)]['name'], element])
toprint = sorted(toprint, key=out1, reverse=True)
for element in toprint:
    print(element[0], element[1])
# Out:
# nfts 348.5788829557897
# blockchain 48.62058259041529
# token 37.139757539497765
# crypto 20.761291009751687

# %%
kwid
# Out:
# {'10clouds': 1,
#  '34 attack': 2,
#  '4everland': 3,
#  '51 attack': 4,
#  '51 attacks': 4,
#  'aleph': 5,
#  'algorand': 6,
#  'algorithmic stablecoins': 7,
#  'algorithmic stable coins': 7,
#  'algorithmic stablecoin': 7,
#  'algorithmic stable coin': 7,
#  'alphatoken': 8,
#  'alphawallet': 9,
#  'altcoin': 10,
#  'altcoins': 10,
#  'amazix': 11,
#  'anchor': 12,
#  'ape yacht club': 13,
#  'apecoin': 14,
#  'arbitrage': 15,
#  'arbitrum': 16,
#  'architecture': 17,
#  'archive node': 18,
#  'arctouch': 19,
#  'artificial intelligence': 20,
#  'ai': 20,
#  'asset tokenization': 21,
#  'asymmetric cryptography': 22,
#  'atom': 23,
#  'atomic swaps': 24,
#  'attarius': 25,
#  'attarius network': 25,
#  'augmented reality': 26,
#  'ar': 26,
#  'authentication': 27,
#  'autoglyphs': 28,
#  'autoglyph': 28,
#  'automated trading': 29,
#  'autonopoulos': 30,
#  'avalanche': 31,
#  'axie infinity': 32,
#  'axieinfinity': 32,
#  'backed stablecoin': 33,
#  'backed stablecoins': 33,
#  'backed stable coin': 33,
#  'backed stable coins': 33,
#  'basic attention token': 34,
#  'basic attention tokens': 34,
#  'batman': 35,
#  'bigchaindb': 36,
#  'binance': 37,
#  'binance launchpad': 38,
#  'binance margin trading': 39,
#  'binance smart chain': 40,
#  'bit country': 41,
#  'bitcoin': 42,
#  'btc': 42,
#  'bitcoins': 42,
#  'bitcoin cash': 43,
#  'bitcoin dominance': 44,
#  'bitcoin etf': 45,
#  'bitcoin etfs': 45,
#  'bitcoin forks': 46,
#  'bitcoin fork': 46,
#  'bitcoin mining': 47,
#  'bitcointalk': 48,
#  'bitmain': 49,
#  'bitmex': 50,
#  'bitshares': 51,
#  'bittorrent': 52,
#  'bittrex': 53,
#  'bitwala': 54,
#  'block lattice': 55,
#  'block size': 56,
#  'blockchain': 57,
#  'blockchain technology': 57,
#  'blockchain technologies': 57,
#  'blockchain app factory': 58,
#  'blockchain association': 59,
#  'blockchain bridge': 60,
#  'blockchain design': 61,
#  'blockchain gaming': 62,
#  'web3 games': 62,
#  'web3 gaming': 62,
#  'blockchain games': 62,
#  'crypto gaming': 62,
#  'crypto games': 62,
#  'blockchain quality engineer': 63,
#  'blockchain scalability problem': 64,
#  'blockchain security': 65,
#  'blockchain size': 66,
#  'blockcypher': 67,
#  'blockfi': 68,
#  'blockfolio': 69,
#  'blockscale': 70,
#  'block scale': 70,
#  'blockspace': 71,
#  'blockstack': 72,
#  'bnb chain': 73,
#  'bored ape': 74,
#  'bsc wallet': 75,
#  'bug bounties': 76,
#  'bug bounty': 76,
#  'buildscape': 77,
#  'byzantine fault tolerance': 78,
#  'byzantine generals problem': 79,
#  'byzantine general problem': 79,
#  'callisto': 80,
#  'cardano': 81,
#  'cardano blockchain': 81,
#  'carlota': 82,
#  'casper network': 83,
#  'casper networks': 83,
#  'casperlabs': 84,
#  'cdx': 85,
#  'celo': 86,
#  'cennznet': 87,
#  'censorship': 88,
#  'centralised crypto exchanges': 89,
#  'centralized crypto exchanges': 89,
#  'centralised crypto exchange': 89,
#  'centralized crypto exchange': 89,
#  'centralised exchanges': 90,
#  'centralized exchanges': 90,
#  'centralised network': 91,
#  'centralized network': 91,
#  'centralized': 92,
#  'centralised': 92,
#  'cloud mining': 93,
#  'codenotary': 94,
#  'codezeros': 95,
#  'coinbase': 96,
#  'coinbase wallet': 97,
#  'coincheck': 98,
#  'coinfabrik': 99,
#  'coinjoin': 100,
#  'coinmama': 101,
#  'coinstats': 102,
#  'coinvest': 103,
#  'cold wallet': 104,
#  'cold wallets': 104,
#  'collateralised': 105,
#  'collateralized': 105,
#  'collateralization': 105,
#  'collateralisation': 105,
#  'collateralised debt': 106,
#  'collateralized debt': 106,
#  'collateralised stablecoin': 107,
#  'collateralized stablecoin': 107,
#  'collateralised stablecoins': 107,
#  'collateralized stablecoins': 107,
#  'commodity backed': 108,
#  'composability': 109,
#  'concordium': 110,
#  'consensus': 111,
#  'consensus mechanisms': 111,
#  'consensus mechanism': 111,
#  'consensus algorithm': 111,
#  'consensus algorithms': 111,
#  'consensus protocols': 111,
#  'consensus protocol': 111,
#  'consensus method': 111,
#  'consensus methods': 111,
#  'consortium blockchain': 112,
#  'consortia': 112,
#  'consortium': 112,
#  'coral protocol': 113,
#  'corda': 114,
#  'corda blockchain': 114,
#  'corda workspace': 115,
#  'cordapp': 116,
#  'cortex': 117,
#  'cosmos': 118,
#  'counterfeit drugs': 119,
#  'counterfeit drug': 119,
#  'cpchain': 120,
#  'cronos': 121,
#  'cross chain bridges': 122,
#  'cross chain bridge': 122,
#  'cross chain update': 123,
#  'crowdcreate': 124,
#  'crypterium': 125,
#  'crypto asset': 126,
#  'crypto assets': 126,
#  'cryptoasset': 126,
#  'cryptoassets': 126,
#  'crypto bank': 127,
#  'crypto compliance': 128,
#  'cryptocurrency compliance': 128,
#  'crypto custody': 129,
#  'crypto exchange': 172,
#  'crypto lending': 131,
#  'cryptocurrency lending': 131,
#  'crypto liquidity': 132,
#  'cryptocurrency liquidity': 132,
#  'crypto mining': 133,
#  'mining': 133,
#  'blockchain mining': 133,
#  'cryptocurrency mining': 133,
#  'crypto shilling': 134,
#  'cryptocurrency shilling': 134,
#  'crypto staking platform': 135,
#  'crypto staking platforms': 135,
#  'crypto tax': 136,
#  'crypto wallet': 137,
#  'crypto wallets': 137,
#  'cryptocurrency wallet': 137,
#  'cryptocurrency wallets': 137,
#  'blockchain wallet': 137,
#  'blockchain wallets': 137,
#  'cryptocompare': 138,
#  'cryptocurrency': 139,
#  'cryptocurrencies': 139,
#  'crypto': 139,
#  'cryptoderivatives': 140,
#  'cryptoeconomics': 141,
#  'crypto economic': 141,
#  'cryptoeconomic': 141,
#  'cryptographic hash': 142,
#  'cryptographic hashing': 142,
#  'cryptography': 143,
#  'cryptohopper': 144,
#  'cryptokitties': 145,
#  'cryptomarket': 146,
#  'cryptonite': 147,
#  'cryptopunk': 148,
#  'cryptopunks': 148,
#  'crypto punk': 148,
#  'crypto punks': 148,
#  'cryptos': 149,
#  'curve dao token': 150,
#  'custodial nft': 151,
#  'custodial nfts': 151,
#  'custodial wallet': 152,
#  'custodial wallets': 152,
#  'custodian': 153,
#  'cyber attacks': 154,
#  'cyber attack': 154,
#  'cyberattack': 154,
#  'cyberattacks': 154,
#  'cybersecurity': 155,
#  'dai': 156,
#  'dao': 157,
#  'decentralised autonomous organisation': 157,
#  'decentralized autonomous organization': 157,
#  'decentralised autonomous organisations': 157,
#  'decentralized autonomous organizations': 157,
#  'daos': 157,
#  'dao maker': 158,
#  'daolaunch': 159,
#  'dappchains': 160,
#  'dappchain': 160,
#  'dapps': 161,
#  'decentralised applications': 161,
#  'decentralised application': 161,
#  'decentralized applications': 161,
#  'decentralized application': 161,
#  'dapp': 161,
#  'decentralised app': 161,
#  'decentralized app': 161,
#  'dark web': 162,
#  'dash': 163,
#  'dash platform': 163,
#  'ddos attack': 164,
#  'ddos attacks': 164,
#  'debt security': 165,
#  'decentraland': 166,
#  'decentralised': 167,
#  'decentralized': 167,
#  'decentralisation': 167,
#  'decentralization': 167,
#  'decentralised cloud computing': 168,
#  'decentralized cloud computing': 168,
#  'decentralised cloud storage': 169,
#  'decentralized cloud storage': 169,
#  'decentralised custody': 170,
#  'decentralized custody': 170,
#  'decentralised database': 171,
#  'decentralized database': 171,
#  'decentralised data': 171,
#  'decentralized data': 171,
#  'decentralised exchange': 172,
#  'decentralised exchanges': 172,
#  'decentralized exchange': 172,
#  'decentralized exchanges': 172,
#  'cryptocurrency exchange': 172,
#  'decentralised governance': 173,
#  'decentralized governance': 173,
#  'decentralised identity': 174,
#  'decentralized identity': 174,
#  'decentralised identities': 174,
#  'decentralized identities': 174,
#  'decentralised internet': 175,
#  'decentralized internet': 175,
#  'decentralised marketplaces': 176,
#  'decentralised marketplace': 176,
#  'decentralized marketplaces': 176,
#  'decentralized marketplace': 176,
#  'decentralised network': 177,
#  'decentralized network': 177,
#  'decentralised social media': 178,
#  'decentralized social media': 178,
#  'decentralised society': 179,
#  'decentralized society': 179,
#  'decentralised storage': 180,
#  'decentralized storage': 180,
#  'decentralised system': 181,
#  'decentralised systems': 181,
#  'decentralized system': 181,
#  'decentralized systems': 181,
#  'decentralised web': 182,
#  'decentralized web': 182,
#  'deepfakes': 183,
#  'deepfake': 183,
#  'deep fake': 183,
#  'deep fakes': 183,
#  'defi': 184,
#  'decentralised finance': 184,
#  'decentralized finance': 184,
#  'defi ecosystem': 185,
#  'defi insurance': 186,
#  'defi loans': 187,
#  'defi protocols': 188,
#  'defi protocol': 188,
#  'defichain': 189,
#  'defi chain': 189,
#  'deflationary cryptocurrencies': 190,
#  'deflationary crypto': 190,
#  'deflationary cryptocurrency': 190,
#  'delegated proof of stake': 191,
#  'dpos': 191,
#  'denial of service': 192,
#  'digital art': 193,
#  'digital assets': 194,
#  'digital currencies': 195,
#  'digital currency': 195,
#  'digital democracy': 196,
#  'digital signature': 197,
#  'digital signatures': 197,
#  'distributed computing': 198,
#  'distributed ledgers': 199,
#  'distributed ledger': 199,
#  'distributed ledger technology': 199,
#  'docker': 200,
#  'doge coin': 201,
#  'dogecoin': 201,
#  'double spending': 202,
#  'double spending problem': 202,
#  'dragonchain': 203,
#  'easyfi': 204,
#  'eclipse attack': 205,
#  'ecosystem fund': 206,
#  'eip 1559': 207,
#  'electroneum': 208,
#  'electrum': 209,
#  'elliptic curve cryptography': 210,
#  'elon musk': 211,
#  'end to end encryption': 212,
#  'enjin coin': 213,
#  'enterprise ethereum': 214,
#  'enterprise ethereum alliance': 215,
#  'enterprise nft': 216,
#  'enterprise nfts': 216,
#  'equity token offerings': 217,
#  'equity token offering': 217,
#  'erc 1155': 218,
#  'erc1155': 218,
#  'erc 1450': 219,
#  'erc1450': 219,
#  'erc 721': 220,
#  'erc721': 220,
#  'erc 777': 221,
#  'erc777': 221,
#  'erc20': 222,
#  'erc 20': 222,
#  'escrow smart contract': 223,
#  'escrow smart contracts': 223,
#  'etfs': 224,
#  'etf': 224,
#  'exchange traded fund': 224,
#  'exchange traded funds': 224,
#  'eth': 225,
#  'ether': 225,
#  'ethdenver': 226,
#  'etherbots': 227,
#  'ether bots': 227,
#  'etherbot': 227,
#  'ether bot': 227,
#  'etherdelta': 228,
#  'ethereum': 229,
#  'ethereum blockchain': 229,
#  'ethereum later': 230,
#  'ethereum name service': 231,
#  'ethereum virtual machine': 232,
#  'ethereum workspace': 233,
#  'ethermint': 234,
#  'etherscan': 235,
#  'ethino': 236,
#  'etoro': 237,
#  'everipedia': 238,
#  'exodus': 239,
#  'fan tokens': 240,
#  'fan token': 240,
#  'faucet': 241,
#  'federated learning': 242,
#  'fiat backed stable coin': 243,
#  'fiat backed stable coins': 243,
#  'fiat backed stablecoin': 243,
#  'fiat backed stablecoins': 243,
#  'fiat money': 244,
#  'fiat': 244,
#  'fiat currency': 244,
#  'financial nfts': 245,
#  'financial nft': 245,
#  'fintrux': 246,
#  'forking': 247,
#  'fork': 247,
#  'forks': 247,
#  'forte': 248,
#  'fractional nft': 249,
#  'fractional nfts': 249,
#  'fractional ownership': 250,
#  'fractional owner': 250,
#  'fractionalization': 251,
#  'game theory': 252,
#  'gamefi': 253,
#  'ganache': 254,
#  'gas': 255,
#  'eth gas': 255,
#  'ether gas': 255,
#  'ethereum gas': 255,
#  'gas fees': 256,
#  'gas price': 256,
#  'gas limit': 257,
#  'genesis block': 258,
#  'gig economy': 259,
#  'global expertise bank': 260,
#  'gravity dex': 261,
#  'hackatom': 262,
#  'hack atom': 262,
#  'halving': 263,
#  'hard forks': 264,
#  'hard fork': 264,
#  'hardhat': 265,
#  'hardware wallets': 266,
#  'hardware wallet': 266,
#  'hash': 267,
#  'hashes': 267,
#  'hash function': 268,
#  'hashing function': 268,
#  'hash rate': 269,
#  'hashrate': 269,
#  'hashgraph': 270,
#  'hash graph': 270,
#  'hashing': 271,
#  'hashlock': 272,
#  'healthcare': 273,
#  'hedera hash graph': 274,
#  'hedera hashgraph': 274,
#  'heimdall layer': 275,
#  'helium': 276,
#  'hive': 277,
#  'holochain': 278,
#  'holonfts': 279,
#  'homomorphic encryption': 280,
#  'hot wallet': 281,
#  'hot wallets': 281,
#  'humanode': 282,
#  'hybrid blockchain': 283,
#  'hybrid security': 284,
#  'hybrid securities': 284,
#  'hyper ledger composer': 285,
#  'hyperledger composer': 285,
#  'hyper ledger iroha': 286,
#  'hyperledger iroha': 286,
#  'hyperledger': 287,
#  'hyper ledger': 287,
#  'hyperledger fabric': 288,
#  'hyper ledger fabric': 288,
#  'identity mining': 289,
#  'ignite': 290,
#  'immutability': 291,
#  'impermanent loss': 292,
#  'infura': 293,
#  'ingot coin': 294,
#  'initial coin offering': 295,
#  'ico': 295,
#  'initial coin offerings': 295,
#  'initial exchange offering': 296,
#  'inter ledger protocol': 297,
#  'interledger protocol': 297,
#  'interchain': 298,
#  'interchain security': 299,
#  'internet of blockchains': 300,
#  'internet of blockchain': 300,
#  'internet of things': 301,
#  'iot': 301,
#  'interoperability': 302,
#  'blockchain interoperability': 302,
#  'iotex': 303,
#  'ipfs': 304,
#  'kardiachain': 305,
#  'kodakcoin': 306,
#  'koinos': 307,
#  'kraken': 308,
#  'kubernetes': 309,
#  'kurtosis': 310,
#  'kyc': 311,
#  'launchpads': 312,
#  'layer': 313,
#  'layer one': 314,
#  'layer 1': 314,
#  'layerone': 314,
#  'layer zero': 315,
#  'layerzero': 315,
#  'layer 0': 315,
#  'lightning network': 316,
#  'limechain': 317,
#  'liquid democracy': 318,
#  'liquid network': 319,
#  'liquid staking': 320,
#  'liquidity': 321,
#  'liquidity mining': 322,
#  'liquidity network': 323,
#  'liquidity pool': 324,
#  'liquidity pools': 324,
#  'liquidity provider': 325,
#  'liquidity providers': 325,
#  'litecoin': 326,
#  'luna': 327,
#  'machine learning': 328,
#  'magic internet money': 329,
#  'mapping': 330,
#  'mastercoin': 331,
#  'merkle tree': 332,
#  'merkle trees': 332,
#  'meta': 333,
#  'metacert': 334,
#  'metadata': 335,
#  'metafi': 336,
#  'metahash': 337,
#  'metahero': 338,
#  'metamask': 339,
#  'metamask wallet': 340,
#  'metaverse': 341,
#  'metaverses': 341,
#  'meta verse': 341,
#  'meta verses': 341,
#  'metaverse wallet': 342,
#  'metis protocol': 343,
#  'micropayments': 344,
#  'micropayment': 344,
#  'miner extractable value': 345,
#  'mining pool': 346,
#  'minting': 347,
#  'mixbytes': 348,
#  'monero': 349,
#  'money laundering': 350,
#  'moonbeam': 351,
#  'moonbirds': 352,
#  'moore law': 353,
#  'multisig wallets': 354,
#  'multisig wallet': 354,
#  'multisignature wallet': 354,
#  'multisignature wallets': 354,
#  'multisignature': 355,
#  'myetherwallet': 356,
#  'mysql': 357,
#  'mythx': 358,
#  'nano': 359,
#  'network effect': 360,
#  'network layer': 361,
#  'neuromorphic': 362,
#  'newdex': 363,
#  'nft collection': 364,
#  'nft fragmentation': 365,
#  'nft lending': 366,
#  'nft marketplace': 367,
#  'nft marketplaces': 367,
#  'nft platform': 368,
#  'nfts': 369,
#  'nft': 369,
#  'non fungible tokens': 369,
#  'non fungible token': 369,
#  'nodle cash': 370,
#  'non custodial nft': 371,
#  'non custodial nfts': 371,
#  'non custodial wallet': 372,
#  'non custodial wallets': 372,
#  'nonce': 373,
#  'octopus network': 374,
#  'odyssey': 375,
#  'olympus pro': 376,
#  'oneledger': 377,
#  'online art trading': 378,
#  'openbazaar': 379,
#  'openchain': 380,
#  'openfinance': 381,
#  'openledger': 382,
#  'open ledger': 382,
#  'opensea': 383,
#  'openzeppelin': 384,
#  'oracle protocols': 385,
#  'oracle protocol': 385,
#  'oracles': 386,
#  'oracle': 386,
#  'blockchain oracles': 386,
#  'blockchain oracle': 386,
#  'oraclize': 387,
#  'oraclise': 387,
#  'ouroboros': 388,
#  'p2p': 389,
#  'p2p lending': 390,
#  'p2p networks': 391,
#  'pancakeswap': 392,
#  'panther protocol': 393,
#  'parachain': 394,
#  'parachains': 394,
#  'paradex': 395,
#  'parastate': 396,
#  'paxos': 397,
#  'permissioned': 398,
#  'permissioned blockchain': 398,
#  'permissioned blockchains': 398,
#  'permissioned ledger': 399,
#  'permissioned ledgers': 399,
#  'permissionless': 400,
#  'permissionless blockchain': 400,
#  'permissionless blockchains': 400,
#  'phishing attack': 401,
#  'phishing attacks': 401,
#  'play to earn': 402,
#  'p2e': 402,
#  'polkastarter': 403,
#  'polygon': 404,
#  'polygon bridge': 405,
#  'polygon matic': 406,
#  'polynomial commitment': 407,
#  'polyswarm': 408,
#  'portfolio tracker': 409,
#  'postgresql': 410,
#  'power ledger': 411,
#  'prediction market': 412,
#  'privacy coins': 413,
#  'private blockchain': 414,
#  'private blockchains': 414,
#  'private data': 415,
#  'private key': 416,
#  'private keys': 417,
#  'private network': 418,
#  'private transactions': 419,
#  'private transaction': 419,
#  'proof of activity': 420,
#  'proof of authority': 421,
#  'proof of believability': 422,
#  'proof of capacity': 423,
#  'poc': 423,
#  'proof of concept': 424,
#  'proof of history': 425,
#  'poh': 425,
#  'proof of importance': 426,
#  'poi': 426,
#  'proof of inclusion': 427,
#  'proof of publication': 428,
#  'proof of stake': 429,
#  'pos': 429,
#  'proof of weight': 430,
#  'proof of work': 431,
#  'pow': 431,
#  'protocol': 432,
#  'protocols': 432,
#  'public blockchain': 433,
#  'public blockchains': 433,
#  'public key': 434,
#  'public ledger': 435,
#  'quadratic voting': 436,
#  'qualtrics': 437,
#  'quantum computing': 438,
#  'quantum cryptography': 439,
#  'quarkchain': 440,
#  'radix': 441,
#  'rari token': 442,
#  'retrievability': 443,
#  'ricardian contracts': 444,
#  'ricardian contract': 444,
#  'ripple': 445,
#  'ripple coin': 445,
#  'ripplenet': 446,
#  'robinhood': 447,
#  'rollux': 448,
#  'routing attacks': 449,
#  'routing attack': 449,
#  'rug pull': 450,
#  'rug pulls': 450,
#  'satoshi nakamoto': 451,
#  'scalability': 452,
#  'securitisation': 453,
#  'securitization': 453,
#  'security protocol': 454,
#  'security protocols': 454,
#  'security token issuances': 455,
#  'security token issuance': 455,
#  'security token offerings': 456,
#  'security token offering': 456,
#  'security tokens': 457,
#  'security token': 457,
#  'security token blockchain': 457,
#  'security tokens blockchain': 457,
#  'self collateralized': 458,
#  'self collateralised': 458,
#  'self sovereign identity': 459,
#  'selfish mining': 460,
#  'sha 256': 461,
#  'sha256': 461,
#  'sharding': 462,
#  'blockchain sharding': 462,
#  'shard': 462,
#  'shrapnel': 463,
#  'sidetone': 464,
#  'slippage': 465,
#  'slothicorn': 466,
#  'smart city': 467,
#  'smart contract auditing': 468,
#  'smart contract audit': 468,
#  'smart contract platform': 469,
#  'smart contract platforms': 469,
#  'smart contracts': 470,
#  'smart contract': 470,
#  'social tokens': 471,
#  'social trading': 472,
#  'socialfi': 473,
#  'soft fork': 474,
#  'soft forks': 474,
#  'software wallets': 475,
#  'software wallet': 475,
#  'solana': 476,
#  'solana blockchain': 476,
#  'solidity': 477,
#  'sorare': 478,
#  'soulbound token': 479,
#  'soulbound tokens': 479,
#  'spankchain': 480,
#  'sperax': 481,
#  'sphynx network': 482,
#  'stabilisation mechanisms': 483,
#  'stabilization mechanisms': 483,
#  'stabilisation mechanism': 483,
#  'stabilization mechanism': 483,
#  'stablecoin': 484,
#  'stablecoins': 484,
#  'stable coin': 484,
#  'stable coins': 484,
#  'stakeholders': 485,
#  'stakes': 486,
#  'stake': 486,
#  'staking': 487,
#  'star atlas': 488,
#  'staratlas': 488,
#  'steganography': 489,
#  'stellar': 490,
#  'stellar blockchain': 490,
#  'substratum': 491,
#  'supertokens': 492,
#  'supertoken': 492,
#  'supply chain management': 493,
#  'surveymonkey': 494,
#  'sushiswap': 495,
#  'swachhcoin': 496,
#  'switching costs': 497,
#  'switching cost': 497,
#  'sybil attacks': 498,
#  'sybil attack': 498,
#  'symmetric cryptography': 499,
#  'synthetix': 500,
#  'syscoin': 501,
#  'taproot': 502,
#  'tendermint': 503,
#  'terra': 504,
#  'terra virtua': 505,
#  'terragreen': 506,
#  'tezbridge': 507,
#  'third party oracle': 508,
#  'third party oracles': 508,
#  'tierion': 509,
#  'tiptoepunks': 510,
#  'titanium blockchain': 511,
#  'token 2049': 512,
#  'token2049': 512,
#  'token curated registries': 513,
#  'token curated registry': 513,
#  'token design': 514,
#  'token distribution': 515,
#  'token economics': 516,
#  'token swap': 517,
#  'token swaps': 517,
#  'tokenasia': 518,
#  'tokenisation': 519,
#  'tokenization': 519,
#  'tokenised asset': 520,
#  'tokenised assets': 520,
#  'tokenized assets': 520,
#  'tokenized asset': 520,
#  'tokenised funds': 521,
#  'tokenised fund': 521,
#  'tokenized funds': 521,
#  'tokenized fund': 521,
#  'tokenized': 522,
#  'tokenised': 522,
#  'tokenminds': 523,
#  'token minds': 523,
#  'tokenomics': 524,
#  'tokens': 525,
#  'token': 525,
#  'tokflow': 526,
#  'totem': 527,
#  'traceability': 528,
#  'travelchain': 529,
#  'trezor': 530,
#  'trezor hardware wallet': 531,
#  'trezor hardware wallets': 531,
#  'truffle': 532,
#  'truffle suite': 533,
#  'trust crypto wallet': 534,
#  'trusted computing': 535,
#  'two factor authentication': 536,
#  '2 factor authentication': 536,
#  'types of tokens': 537,
#  'uniswap': 538,
#  'unstoppable domains': 539,
#  'unstoppable domain': 539,
#  'usdc': 540,
#  'utility tokens': 541,
#  'utility token': 541,
#  'vectorspace': 542,
#  'velvet capital': 543,
#  'venture capital': 544,
#  'venus': 545,
#  'vesting schedule': 546,
#  'vitalik buterin': 547,
#  'wallet': 548,
#  'wallets': 548,
#  'waverley software': 549,
#  'web3': 550,
#  'white paper': 551,
#  'white papers': 551,
#  'world blockchain summit': 552,
#  'wrapping': 553,
#  'xrapid': 554,
#  'yellow network': 555,
#  'yield farming protocol': 556,
#  'yield farming protocols': 556,
#  'zero knowledge proofs': 557,
#  'zero knowledge proof': 557,
#  'zkps': 557,
#  'zkp': 557,
#  'zero trust': 558,
#  'zignaly': 559,
#  'zk rollups': 560,
#  'zk rollup': 560,
#  'zero knowledge rollups': 560,
#  'zero knowledge rollup': 560,
#  'zksnarks': 561,
#  'zk snarks': 561,
#  'zksnark': 561,
#  'zkstarks': 562,
#  'zkstark': 562,
#  'zk stark': 562,
#  'zk starks': 562,
#  'hash table': 563,
#  'hash tables': 563,
#  'defi wallet': 564,
#  'defi wallets': 564,
#  'scantrust': 565,
#  'hyperledger indy': 566,
#  'hyper ledger indy': 566,
#  'sap cloud': 567,
#  'quorum blockchain': 568,
#  'defi token': 569,
#  'defi tokens': 569,
#  'world economic forum': 570,
#  'trapdoor function': 571,
#  'scriptpubkey': 572,
#  'encryption': 573,
#  'public key encryption': 574,
#  'private key encryption': 575,
#  'public key cryptography': 576,
#  'private key cryptography': 577,
#  'digital dollar wallet': 578,
#  'hyperledger besu': 579,
#  'hyper ledger besu': 579,
#  'hyperledger burrow': 580,
#  'hyper ledger burrow': 580,
#  'hyperledger quilt': 581,
#  'hyper ledger quilt': 581,
#  'decentralised identifier': 582,
#  'decentralised identifiers': 582,
#  'decentralized identifier': 582,
#  'decentralized identifiers': 582,
#  'internet of money': 583,
#  'haul carrier': 584,
#  'cryptographic algorithms': 585,
#  'cryptographic algorithm': 585,
#  'smart contract security': 586,
#  'cyber hacks': 587,
#  'cyber hack': 587,
#  'cyberhacks': 587,
#  'cyberhack': 587,
#  'digital process automation': 588,
#  'contour blockchain': 589,
#  'hyperledger fabric consensus': 590,
#  'nep5': 591,
#  'nep8': 592,
#  'zeepin': 593,
#  'moonlight': 594,
#  'bitcoin segwit': 595,
#  'digixdao': 596,
#  'spectrecoin': 597,
#  'ethereum plasma': 598,
#  'ethereum wallet': 599}

# %%
def getminprereqs(searchid, matrix, discriminant=0.2):
    output = []
    cloud = [[searchid, matrix[searchid, searchid]]]
    track = []
    track.append(searchid)
    while True:
        id_ = cloud.pop(0)[0]
        list_ = list(matrix[id_])
        for element in range(len(list_)):
            if element==id_:
                continue
            if list_[element]>discriminant*max(list_):
                if element not in track:
                    cloud.append([element, list_[element]])
                    track.append(element)
        cloud = sorted(cloud, key=out0, reverse=True)
        output.append(id_)
        if len(cloud)==0:
            break
    return output

def printprereqs(kwdata, searchid, matrix):
    get = getminprereqs(searchid, matrix)
    while True:
        if len(get)!=0:
            print(kwdata[get.pop()]['name'])
        else:
            break

# %%
printprereqs(kwdata, kwid['proof of work'], matrix)
# Out:
# bitcoin
# blockchain
# centralized
# consensus
# mining
# crypto
# defi
# decentralized
# dpos
# security tokens
# staking
# token
# stake
# proof of stake
# proof of work

# %%
kwdata[kwid['proof of work']]
# Out:
# {'synonyms': {'proof of work': 1397, 'pow': 817},
#  'total': 2214,
#  'name': 'proof of work'}

# %%
def getnexttopics(searchid, matrix, discriminant=0.7):
    output = []
    cloud = []
    pass

# %%
name_ = 'blockchain'
for i in range(len(matrix[:, kwid[name_]])):
    if matrix[:, kwid[name_]][i]>0.02*(max(matrix[:, kwid[name_]])):
        print(kwdata[i])
# Out:
# {'synonyms': {'bitcoin': 9028, 'btc': 841, 'bitcoins': 572}, 'total': 10441, 'name': 'bitcoin'}
# {'synonyms': {'blockchain': 46929, 'blockchain technology': 5534, 'blockchain technologies': 325}, 'total': 52788, 'name': 'blockchain'}
# {'synonyms': {'cryptocurrency': 6889, 'cryptocurrencies': 3961, 'crypto': 12307}, 'total': 23157, 'name': 'crypto'}
# {'synonyms': {'decentralised': 441, 'decentralized': 6812, 'decentralisation': 148, 'decentralization': 2035}, 'total': 9436, 'name': 'decentralized'}
# {'synonyms': {'ethereum': 8691, 'ethereum blockchain': 1006}, 'total': 9697, 'name': 'ethereum'}
# {'synonyms': {'hyperledger': 2337, 'hyper ledger': 12}, 'total': 2349, 'name': 'hyperledger'}
# {'synonyms': {'smart contracts': 4772, 'smart contract': 3123}, 'total': 7895, 'name': 'smart contracts'}
# {'synonyms': {'tokens': 6177, 'token': 6419}, 'total': 12596, 'name': 'token'}

# %% [markdown]
# ### conditional probability graphs

# %%
import matplotlib.pyplot as plt
   
name_ = 'white paper'
X = [key for key in kwdata if key!=kwid[name_]]
Y = [matrix[kwid[name_]][i] for i in range(len(matrix[kwid[name_]])) if i!=kwid[name_]]

plt.plot(X, Y)
plt.title(f"Occurance of '{name_}'")
plt.xlabel('kws')
plt.ylabel('frequency')
plt.show()

# %%
# print the n-most related topics
def topnprereqs(searchid, matrix):
    temp = []
    for i in range(len(matrix[searchid])):
        if i!=searchid:
            temp.append([i, matrix[searchid, i]])
    temp = sorted(temp, key=out1, reverse=True)
    return temp

# %%
import matplotlib.pyplot as plt
   
name_ = 'white paper'
XY = topnprereqs(kwid[name_], matrix)
X = [element for element in range(len(XY))]
Y = [element[1] for element in XY]

plt.plot(X, Y)
plt.title(f"Occurance of '{name_}'")
plt.xlabel('kws')
plt.ylabel('frequency')
plt.show()
# some

# %%
# 80-20% principle
def gettopconnections(searchid, matrix, kwdata):
    totalsum = sum(sum(matrix))
    returnthis = []
    sigma = sum(matrix[searchid])
    temp = topnprereqs(searchid, matrix)
    tempsum = 0
    i = 0
    while True:
        returnthis.append(temp[i][0])
        tempsum+=temp[i][1]
        P = sum(matrix[:, temp[i][0]])/totalsum
        p = matrix[searchid, temp[i][0]]/sum(matrix[searchid])
        print(f"P({kwdata[temp[i][0]]['name']}):{P}, P({kwdata[temp[i][0]]['name']}|{kwdata[searchid]['name']}):{p}")
        if tempsum>0.2*sigma:
            break
        i+=1
    return returnthis

# %%
a = [kwdata[element]['name'] for element in gettopconnections(kwid['wallet'], matrix, kwdata)]
a
# Out:
# P(crypto):0.07166260991849793, P(crypto|wallet):0.08664560514867202
# P(blockchain):0.2116505567452529, P(blockchain|wallet):0.053025253967842585
# P(crypto wallet):0.0026112433305101423, P(crypto wallet|wallet):0.04607801443417855
# P(token):0.050654252741771905, P(token|wallet):0.0336926796247874
# ['crypto', 'blockchain', 'crypto wallet', 'token']

# %%
matrix[kwid['blockchain'], kwid['blockchain']]
# Out:
# 2929.8276558926705

# %%
import matplotlib.pyplot as plt

name_ = 'metamask'
totalsum = sum(sum(matrix))
X = [element for element in range(len(matrix)) if element!=kwid[name_]]
Y1 = [sum(matrix[:, element])/totalsum for element in range(len(matrix)) if element!=kwid[name_]]
Y2 = [matrix[kwid[name_], element]/sum(matrix[kwid[name_]]) for element in range(len(matrix)) if element!=kwid[name_]]

plt.plot(X, Y1)
plt.plot(X, Y2)
plt.title(f"Occurance of '{name_}'")
plt.xlabel('kws')
plt.ylabel('frequency')
plt.show()
