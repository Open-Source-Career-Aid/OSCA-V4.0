# %%
import sys
sys.path.insert(1, '/Users/chinmayshrivastava/Desktop/OSCA/V4.0/scraping/crawler')
from generalscraper import *

# %%
paragraphs = pd.DataFrame(columns=['databaseid', 'tag', 'text', 'links'])
headings = pd.DataFrame(columns=['databaseid', 'tag', 'headingtext', 'subheading', 'nextheading', 'paragraphs'])
database = pd.DataFrame(columns=['topicheadingID', 'url', 'totalsubheadings', 'totalparagraphs'])

# %%
kwdata = pd.read_pickle('synonymsdata.pickle')
urlscraped = {}
urlstoscrape = []
kwanalyzed = {}

# %%
# i=0
kws_ = 0
howmanydocuments = 0
for kwid in kwdata:
#     i+=1
    if kwid == 0:
        continue
    if kwdata[kwid]['name'] in kwanalyzed:
        continue
    if kws_==2:
        break
    kws_ += 1
    
    print('Analysing:', kwdata[kwid]['name'])
    q = f"what is {kwdata[kwid]['name']} blockchain"
    engine = Google()
    results = engine.search(q)
    links = results.links()
    
    clear_output(wait=True)
    
    if len(links)<10:
        time.sleep(120)
        continue
    
    kwanalyzed[kwdata[kwid]['name']] = len(links)
    
    i = 0
    
    for url in links:
        
        i+=1
        print((i*100)/len(links))
        
        host = get_host_and_path(url)[0]
        try:
            url = urlcheck(url, host)
        except:
            continue
        print('scraping', url)
        
        if url in urlscraped:
            continue
        try:
            if url[-3:] == 'pdf':
                urlscraped[url] = False
                continue
            document_, headings_, paragraphs_ = articlescraper(url, len(database.index), dynamic=True)
        except:
            urlscraped[url] = False
            continue
        
        if adddocument(headings_, paragraphs_):
            # append to the database
            database.loc[len(database.index)] = document_
            for element in headings_:
                headings.loc[len(headings.index)] = element
            for element in paragraphs_:
                paragraphs.loc[len(paragraphs.index)] = element
            howmanydocuments += 1
            print('document added successfully!')
            urlscraped[url] = True
        else:
            print('document was rejected!')
            urlscraped[url] = False
            continue
        
        for element in paragraphs_:
            if len(element[3])!=0:
                for subelement in element[3]:
#                     print(subelement)
                    if subelement[0] not in urlscraped:
                        urlstoscrape.append(subelement[0])
#                     clear_output(wait=True)

    clear_output(wait=True)
    
    print(howmanydocuments, "have been successfully scraped!")
    if howmanydocuments%10000==0:
        integer = howmanydocuments/10000
        with open(f'generaldatabase{integer}.pickle', 'wb') as file:
            pickle.dump(database, file)
        with open(f'generalheadings{integer}.pickle', 'wb') as file:
            pickle.dump(headings, file)
        with open(f'generalparagraphs{integer}.pickle', 'wb') as file:
            pickle.dump(paragraphs, file)
        paragraphs = pd.DataFrame(columns=['databaseid', 'tag', 'text', 'links'])
        headings = pd.DataFrame(columns=['databaseid', 'tag', 'headingtext', 'subheading', 'nextheading', 'paragraphs'])
        database = pd.DataFrame(columns=['topicheadingID', 'url', 'totalsubheadings', 'totalparagraphs'])
#     break
#     print(q, len(links), len(urlscraped), i)
# Out:
# document was rejected!
# 60.583941605839414
# scraping None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b2684a434f3e> in <module>
#      40         print('scraping', url)
#      41
# ---> 42         if url[-3:] == 'pdf':
#      43             urlscraped[url] = False
#      44             continue
#
# TypeError: 'NoneType' object is not subscriptable

# %%
urlscraped
# Out:
# {'https://10clouds.com/': True,
#  'https://au.linkedin.com/company/10clouds-com': True,
#  'https://www.techerati.com/features-hub/interviews/the-future-of-blockchain-with-10clouds/': False,
#  'https://www.youtube.com/watch?v=zeoaDx3dE5A': False,
#  'https://twitter.com/10clouds': True,
#  'https://stripe.com/partners/directory/10clouds': True,
#  'https://web3.career/senior-blockchain-developer-10clouds/19627': True,
#  'https://www.crunchbase.com/organization/10clouds-aed5': True,
#  'https://alephzero.org/ecosystem/10-clouds/': True,
#  'https://www.facebook.com/10Clouds/': False,
#  'https://mambu.com/partner/10-clouds': True,
#  'https://www.designrush.com/agency/profile/10clouds': True,
#  'https://www.homeofcrypto.co/company/10clouds/': False,
#  'https://www.cryptotask.org/en/clients/10clouds/10153': True,
#  'https://clutch.co/profile/10clouds': True,
#  'https://apply.workable.com/10clouds/j/D5351B5E8D/apply/': True,
#  'https://www.instagram.com/10clouds/?hl=en': False,
#  'https://dribbble.com/10Clouds/projects/1429268-Coinquista': True,
#  'https://www.upwork.com/o/companies/~0125dfad0703cd9bea/': False,
#  'https://www.behance.net/search/projects/?locale=en_US&search=10Clouds.': True,
#  'https://www.glassdoor.co.in/Overview/Working-at-10Clouds-EI_IE858894.11,19.htm': True,
#  'https://interexy.com/top-10-blockchain-development-companies-in-2022/': True,
#  'https://itrate.co/company/10clouds': True,
#  'https://www.found.dev/companies/10clouds': False,
#  'https://nofluffjobs.com/job/senior-blockchain-developer-10clouds-remote-35zrhpq6': False,
#  'https://www.pinterest.com/pin/361413938846752375/': False,
#  'https://www.crowdcast.io/e/10CTech-Blockchain': True,
#  'https://www.goodfirms.co/company/10clouds': True,
#  'https://themanifest.com/pl/blockchain/ethereum/companies': True,
#  'https://www.emailveritas.com/url-checker/10clouds-com': True,
#  'https://www.stgeorgesnashville.org/app.aspx': False,
#  'http://weblisting.freetemplatespot.com/10clouds.com': True,
#  'https://medium.com/beautiful-code-smart-design-by-10clouds/9-unexpected-ways-to-use-the-blockchain-beyond-bitcoin-b0bf7181a03f': True,
#  'https://www.businesswire.com/news/home/20180725005755/en/India-Blockchain-Technology-Market-2018-2023-Top-Blockchain-Consulting-Firms-are-Microsoft-Deloitte-Tata-Consultancy-Services-and-Wipro---ResearchAndMarkets.com': True,
#  'https://www.scam-detector.com/validator/10clouds-com-review/': True,
#  'https://rocketreach.co/seungki-yeo-email_66946221': True,
#  'https://www.appfutura.com/blog/top-20-blockchain-app-development-companies-october-2018/': True,
#  'https://blackmagic.so/glance/10Clouds': True,
#  'https://www.finextra.com/bloggers/141309': False,
#  'https://gcoin.com/recent-news/': True,
#  'https://techreviewer.co/companies/10clouds': True,
#  'https://influencermarketinghub.com/blockchain-consulting-services/': True,
#  'https://www.truefirms.co/company/10Clouds/266': False,
#  'https://colorswall.com/palette/184544': True,
#  'https://m.intrepidmuseum.org/app.aspx': False,
#  'https://www.openpr.com/news/1566015/india-blockchain-technology-market-analysis-and-growth-by-top-manufacturers-s-pro-consagous-technologies-10clouds-sofocle-technologies-and-sate-development.html': True,
#  'https://blog.goodaudience.com/top-10-blockchain-software-development-companies-in-eastern-europe-a171c12cc9dc': True,
#  'https://www.n-ix.com/top-10-blockchain-software-development-companies-europe/': True,
#  'https://www.bizofit.com/business-directory/10-clouds/': True,
#  'https://kepler.finance/products-and-services/': False,
#  'https://www.g2.com/products/10clouds/competitors/alternatives': True,
#  'https://github.com/10clouds': True,
#  'https://www.digitaljournal.com/pr/dapps-market-emerging-trend-by-key-players-consensys-blockchain-intelligence-group-inc-solulab-inc-arctouch-inc-10clouds': True,
#  'https://www.topdevelopers.co/profile/10clouds': True,
#  'https://appdevelopmentcompanies.co/local-agencies/us/blockchain/app-developers/atlanta': False,
#  'https://www.marketresearch.com/Netscribes-India-Pvt-Ltd-v3676/India-Blockchain-Technology-11761036/': True,
#  'https://hackernoon.com/19-top-blockchain-development-companies-89f6e55699': True,
#  'https://www.techasoft.com/post/top-10-blockchain-development-companies-in-usa': True,
#  'https://www.zoominfo.com/c/gentle-ninja/356541991': True,
#  'https://inge-tech.com.mx/ihvnef/blockchain-developer-portfolio': False,
#  'https://topappdevelopmentcompanies.com/us/directory/blockchain-developers/converse-us': True,
#  'https://www.iqvis.com/blog/top-10-blockchain-development-companies-usa/': True,
#  'https://mainstagenews.app/10clouds-offers-one-stop-shop-for-digital-product-design-and-development/': True,
#  'https://mediashower.com/blog/best-blockchain-development-firms/': True,
#  'https://investmentbank.com/blockchain-cloud-computing/': False,
#  'https://www.gettysburgfoundation.org/tnew/app.aspx': False,
#  'https://aravanlabs.com.uy/5hd7ns/38517923ac39e82c': True,
#  'https://guardtime.com/blog/blockcloud-re-inventing-cloud-with-blockchains': True,
#  'https://tramiteschile.com/pnhq/5527233544e10f6555': True,
#  'https://books.google.com/books?dq=what+is+10clouds+blockchain&hl=en&id=QsNuEAAAQBAJ&lpg=PT120&ots=Lmzamo2ICz&pg=PT120&sa=X&sig=ACfU3U0SiOujYHC8GRnubSUWoaFIwFyxIA&source=bl&ved=2ahUKEwjE2YSu9J_6AhW8hf0HHT13A8M4RhDoAXoECAIQAw': False,
#  'https://acloudguru.com/blog/engineering/blockchain-cloud-comparison-what-is-blockchain-as-a-service-baas': True,
#  'https://www.section.io/engineering-education/understanding-the-51-attack-on-blockchain/': True,
#  'https://learn.bybit.com/en/blockchain/what-is-51-attack/': True,
#  'https://www.investopedia.com/terms/1/51-attack.asp': True,
#  'https://freemanlaw.com/blockchain-attacks-is-no-one-safe-in-the-world-of-cryptocurrencies/': True,
#  'https://stormgain.com/blog/51-percent-attack': True,
#  'https://www.coindesk.com/learn/what-is-a-51-attack/': True,
#  'https://www.mdpi.com/2076-3417/9/9/1788/htm': True,
#  'https://cryptoarmy.io/what-is-a-51-attack-on-blockchain-and-bitcoin/': True,
#  'https://thelayer.xyz/a-quick-guide-to-51-attack-in-blockchain/': True,
#  'https://golden.com/wiki/51_percent_attack-MN4DX8W': True,
#  'https://privacycanada.net/cryptocurrency/51-attack/': True,
#  'https://link.springer.com/article/10.1007/s11227-022-04370-1': True,
#  'https://www.sciencedirect.com/science/article/pii/S2096720921000166': True,
#  'https://www.cs.cornell.edu/~ie53/publications/btcProcFC.pdf': False,
#  'https://research.csiro.au/data61/wp-content/uploads/sites/85/2016/08/balance_attack.pdf': False,
#  'https://ieeexplore.ieee.org/iel7/6287639/6514899/09567686.pdf': False,
#  'https://www.researchgate.net/publication/331806569_Overview_of_Attack_Surfaces_in_Blockchain': False,
#  'https://academy.bit2me.com/en/ataque-51-bitcoin/': True,
#  'https://www.finyear.com/Is-a-51-attack-a-real-issue_a40851.html': False,
#  'https://crypto.stackexchange.com/questions/97740/why-1-in-51-attack-on-blockchain-network': True,
#  'https://eprint.iacr.org/2018/1211.pdf': False,
#  'https://www.ive.one/glossary/51-attack': True,
#  'https://arxiv.org/pdf/2101.05511': False,
#  'https://nsg.ee.ethz.ch/fileadmin/user_upload/publications/fc21final97.pdf': False,
#  'https://www.bleepingcomputer.com/news/security/cryptocom-confirms-483-accounts-hacked-34-million-withdrawn/': True,
#  'https://economictimes.indiatimes.com/markets/cryptocurrency/what-are-51-attacks-in-cryptocurrencies/articleshow/85802504.cms': True,
#  'https://www.youtube.com/watch?v=BuTj9raHQOU': False,
#  'https://fintelics.medium.com/everything-you-need-to-know-about-the-51-attack-and-blockchain-177a3293ee11': True,
#  'https://hal.archives-ouvertes.fr/hal-01310088v1/document': False,
#  'https://www.oreilly.com/library/view/mastering-bitcoin/9781491902639/ch08.html': True,
#  'https://en.wikipedia.org/wiki/Blockchain': True,
#  'https://purls.library.ucf.edu/go/DP0024201': False,
#  'https://www.cs.umd.edu/~jkatz/papers/whale-txs.pdf': False,
#  'https://www.cnbc.com/2021/10/02/ethereum-had-a-rough-september-heres-why-and-how-it-gets-fixed.html': False,
#  'https://cloudsecurityalliance.org/articles/rent-to-pwn-the-blockchain-51-attacks-made-easy/': True,
#  'https://www2.deloitte.com/content/dam/Deloitte/tr/Documents/technology-media-telecommunications/Blockchain-and-Cyber.pdf': False,
#  'https://dl.acm.org/doi/10.5555/2831143.2831152': True,
#  'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8512294/': False,
#  'https://www.blockchain.com/pools': False,
#  'https://kclpure.kcl.ac.uk/portal/files/157833351/identity_based_pos.pdf': False,
#  'https://www.jbs.cam.ac.uk/wp-content/uploads/2020/08/paper-pagnotta-bitcoinasdecentralisedmoney.pdf': False,
#  'https://www.theblock.co/linked/74130/ethereum-classic-another-51-attack': True,
#  'https://commons.erau.edu/cgi/viewcontent.cgi?article=1551&context=edt': False,
#  'https://hackernoon.com/how-does-blockchain-security-work-anyway': True,
#  'https://www.imf.org/-/media/Files/Publications/FTN063/2022/English/FTNEA2022003.ashx': False,
#  'https://www.steptoe.com/images/content/1/7/v3/171269/LIT-FebMar18-Feature-Blockchain.pdf': False,
#  'https://repository.tcu.edu/bitstream/handle/116099117/43806/09308934(1).pdf?sequence=1': False,
#  'https://d-nb.info/1174992239/34': False,
#  'https://www.dentons.com/en/insights/articles/2022/may/13/taxation-of-crypto-currencies-and-blockchain-transactions': True,
#  'https://support.bitkub.com/hc/en-us/articles/4407005666061-What-exactly-is-a-51-Attack-': True,
#  'https://www.nber.org/system/files/working_papers/w29396/w29396.pdf': False,
#  'https://research-portal.uws.ac.uk/files/11321532/2019_04_26_Sayeed_et_al_Blockchain.pdf': False,
#  'https://anycoindirect.eu/en/blog/51-attack-how-to-take-over-the-blockchain': True,
#  'https://www.bankofcanada.ca/wp-content/uploads/2018/07/swp2018-34.pdf': False,
#  'https://cryptoslate.com/explained-51-percent-attacks-on-bitcoin-cryptocurrencies/': True,
#  'https://coincasso.com/blockchain-academy/what-is-a-51-attack/': True,
#  'https://cointelegraph.com/news/breaking-bsv-reportedly-suffers-massive-51-attack': False,
#  'https://repository.stcloudstate.edu/cgi/viewcontent.cgi?article=1093&context=msia_etds': False,
#  'https://trading-education.com/51-attack-explained-how-to-plummet-the-price-of-a-cryptocurrency': True,
#  'https://www.reddit.com/r/hashgraph/comments/ndlhkj/51_attack_against_owning_more_than_13_of_coins/': True,
#  'https://nvlpubs.nist.gov/nistpubs/ir/2018/nist.ir.8202.pdf': False,
#  'https://tigerprints.clemson.edu/cgi/viewcontent.cgi?article=4335&context=all_theses': False,
#  'https://www.usenix.org/system/files/conference/usenixsecurity15/sec15-paper-heilman.pdf': False,
#  'https://www.europarl.europa.eu/cmsdata/150761/TAX3 Study on cryptocurrencies and blockchain.pdf': False,
#  'https://www.hindawi.com/journals/scn/2020/8839047/': False,
#  'https://u.today/ethereum-on-pow-ethw-users-might-be-vulnerable-to-new-type-of-attack': True,
#  'http://www.ijmlc.org/vol10/942-M114.pdf': False,
#  'https://dci.mit.edu/51-attacks': True,
#  'https://www.coitok.com/34-attack-407': False,
#  'https://www.sec.gov/litigation/investreport/34-81207.pdf': False,
#  'https://www.longhash.com/en/news/3311/It-Now-Costs-Over-140x-More-to-Attack-Bitcoin-Than-Bitcoin-Cash': True,
#  'https://papers.ssrn.com/sol3/Delivery.cfm/SSRN_ID3065857_code2682943.pdf?abstractid=3065857': True,
#  'https://allquantor.at/blockchainbib/pdf/natoli2016balance.pdf': False,
#  'https://decrypt.co/61124/french-government-to-auction-seized-bitcoin-worth-34-5-million': True,
#  'https://engj.org/index.php/ej/article/view/3656/926': False,
#  'https://www.maritime.dot.gov/sites/marad.dot.gov/files/2020-07/Blockchain Use Cases Final Report (20200622).pdf': False,
#  'https://academic.oup.com/cybersecurity/article/3/2/137/4831474': True,
#  'https://crypto.stanford.edu/timings/paper.pdf': False,
#  'https://pennstate.pure.elsevier.com/en/publications/blockchain-and-the-protection-of-patient-information-using-blockc': True,
#  'https://www.investing.com/news/cryptocurrency-news/how-is-facebooks-libra-blockchain-secured-is-it-open-to-a-34-attack-1904088': False,
#  'https://forum.helloiota.com/469/XY-Attack-Vector-IOTAs-version-of-the-34-attack': False,
#  'http://www.iald.org/appPlUkp/19920.pptx': False}

# %%
paragraphs
# Out:
#      databaseid  tag                                               text links
# 0             0    p  We are an agile software company providing bot...    []
# 1             0  uli                    Python & JavaScript Development    []
# 2             0  uli                     Django & DjangoCMS Development    []
# 3             0  uli                   Angular, React & Vue Development    []
# 4             0  uli                       Node.js & Elixir Development    []
# ...         ...  ...                                                ...   ...
# 3845         90    p                                            EP - 37    []
# 3846         90    p  BT - Proceedings - 2018 4th International Conf...    []
# 3847         90    p  PB - Institute of Electrical and Electronics E...    []
# 3848         90    p             Y2 - 26 July 2018 through 27 July 2018    []
# 3849         90    p                                               ER -    []
#
# [3850 rows x 4 columns]

# %%
isEnglish("Port3 Network We're Hiring")
# Out:
# True

# %%
kwanalyzed
# Out:
# {'10clouds': 64}
