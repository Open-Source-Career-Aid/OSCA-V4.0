# %%
import pandas as pd

# %%
database = pd.read_pickle('databasefromhnandbc101.pickle')
headings = pd.read_pickle('headingsfromhnandbc101.pickle')
paragraphs = pd.read_pickle('paragraphsfromhnandbc101.pickle')

# %%
database
# Out:
#      topicheadingID                                                url  \
# 0                 0  https://hackernoon.com/is-blockchain-based-wat...
# 1                 7  https://hackernoon.com/pros-and-cons-of-develo...
# 2                13  https://hackernoon.com/what-is-stabila-coin-an...
# 3                15  https://hackernoon.com/doodles-a-brand-exceedi...
# 4                21  https://hackernoon.com/self-reliance-is-the-on...
# ...             ...                                                ...
# 8812          64650  https://101blockchains.com/xlm-vs-xrp-which-is...
# 8813          64657  https://101blockchains.com/blockchain-is-a-uni...
# 8814          64661  https://101blockchains.com/whats-all-the-fuss-...
# 8815          64666  https://101blockchains.com/why-blockchain-tech...
# 8816          64673             https://101blockchains.com/monero-xmr/
#
#      totalsubheadings totalparagraphs
# 0                   6              13
# 1                   5              26
# 2                   1              30
# 3                   5              20
# 4                   1              12
# ...               ...             ...
# 8812                6              12
# 8813                3              12
# 8814                4              16
# 8815                6              18
# 8816                9              42
#
# [8817 rows x 4 columns]

# %%
headings
# Out:
#          tag                                        headingtext subheading  \
# 0      topic  Is Blockchain-Based Watch-to-Earn Monetization...          2
# 1         h3                              @ishantechIshanOnTech       None
# 2         h2                                 What Is Happening?       None
# 3         h2                                  What is Coub.com?       None
# 4         h2    How is Coubâs Web3 Video Space Going to Work?       None
# ...      ...                                                ...        ...
# 64678     h3             Pros and Cons of Monero Cryptocurrency       None
# 64679     h3                  How to Buy Monero Cryptocurrency?       None
# 64680     h3                 How to Mine Monero Cryptocurrency?       None
# 64681     h3    How Monero Cryptocurrency Improves the Privacy?       None
# 64682     h3                                        Bottom Line       None
#
#       nextheading                                         paragraphs
# 0            None                                                 []
# 1            None                                                [0]
# 2               3                                                [1]
# 3               4                                             [2, 3]
# 4               5                                       [4, 5, 6, 7]
# ...           ...                                                ...
# 64678       64679  [308864, 308865, 308866, 308867, 308868, 30886...
# 64679       64680                           [308876, 308877, 308878]
# 64680       64681                           [308879, 308880, 308881]
# 64681       64682                           [308882, 308883, 308884]
# 64682        None           [308885, 308886, 308887, 308888, 308889]
#
# [64683 rows x 5 columns]

# %%
paragraphs
# Out:
#        tag                                               text
# 0        p  Covering the latest events, insights and views...
# 1        p  Coub.com, a micro-video streaming social netwo...
# 2        p  Coub is a video-sharing website that is access...
# 3        p  On Coub, users can take any video, trim the be...
# 4        p  In order to preserve the intrinsic fluidity of...
# ...     ..                                                ...
# 308885   p  Cryptocurrencies are increasingly becoming a b...
# 308886   p  You can easily trade Monero on popular cryptoc...
# 308887   p  The popularity of Monero is yet to increase in...
# 308888   p  Join our annual/monthly membership program and...
# 308889   p  *Disclaimer: The article should not be taken a...
#
# [308890 rows x 2 columns]
